# %%
# %matplotlib notebook
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
from matplotlib.dates import AutoDateFormatter, AutoDateLocator

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine,inspect, func,desc

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
#Get Column attributes for measurement
inspector = inspect(engine)
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
#Column attributes for station
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
from datetime import datetime
last_dt = (session.query(Measurement.date).order_by(desc(Measurement.date)).first())
last_dt = datetime.strptime(last_dt[0], '%Y-%m-%d')
last_dt
# Out:
# datetime.datetime(2017, 8, 23, 0, 0)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# Calculate the date 1 year ago from today
# calculated two years before because one year wasn't returning anything
yr_last = last_dt - dt.timedelta(days=365.2422)
# Perform a query to retrieve the data and precipitation scores
query = session.query(Measurement.date, Measurement.prcp). \
    filter(Measurement.date>yr_last).order_by(Measurement.date).all()
# Save the query results as a Pandas DataFrame and set the index to the date column
prcp_df = pd.DataFrame(query, columns =['Date', 'Precipitation'])
prcp_df.set_index('Date', inplace = True)
# Sort the dataframe by date
prcp_df.sort_index()
# Out:
#             Precipitation
# Date
# 2016-08-23           0.00
# 2016-08-23           0.15
# 2016-08-23           0.05
# 2016-08-23            NaN
# 2016-08-23           0.02
# 2016-08-23           1.79
# 2016-08-23           0.70
# 2016-08-24           0.08
# 2016-08-24           2.15
# 2016-08-24           2.28
# 2016-08-24            NaN
# 2016-08-24           1.22
# 2016-08-24           2.15
# 2016-08-24           1.45
# 2016-08-25           0.08
# 2016-08-25           0.08
# 2016-08-25           0.00
# 2016-08-25           0.00
# 2016-08-25           0.21
# 2016-08-25           0.06
# 2016-08-25           0.11
# 2016-08-26           0.00
# 2016-08-26           0.03
# 2016-08-26           0.02
# 2016-08-26           0.04
# 2016-08-26           0.00
# 2016-08-26           0.01
# 2016-08-27           0.00
# 2016-08-27           0.18
# 2016-08-27           0.02
# ...                   ...
# 2017-08-16           0.00
# 2017-08-16           0.07
# 2017-08-16           0.12
# ...

# %%
# Use Pandas Plotting with Matplotlib to plot the data

#dates = list(prcp_df.index.unique())
fig,ax = plt.subplots()
ax.plot(prcp_df.index, prcp_df['Precipitation'])
ax.set(xlabel='Date', ylabel='Precipitation Level',
       title='Precipitation Level over time')


ax.legend()
fig.tight_layout()
fig.autofmt_xdate()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
prcp_df.describe()
# Out:
#        Precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# How many stations are available in this dataset?
station_ct = session.query(Station.station).distinct().count()
station_ct
# Out:
# 9

# %%
# What are the most active stations?
# List the stations and the counts in descending order.
station_active = session.query(Measurement.station, (func.count(Measurement.station).label('Count'))).\
    group_by(Measurement.station).order_by('Count DESC')
for station in station_active:
    print(station)
# Out:
# ('USC00519281', 2772)
# ('USC00519397', 2724)
# ('USC00513117', 2709)
# ('USC00519523', 2669)
# ('USC00516128', 2612)
# ('USC00514830', 2202)
# ('USC00511918', 1979)
# ('USC00517948', 1372)
# ('USC00518838', 511)
# C:\Users\orv2\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:643: SAWarning: Can't resolve label reference 'Count DESC'; converting to text() (this warning may be suppressed after 10 occurrences)
#   util.ellipses_string(element.element))

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?
most_active_st = str('USC00519281')
query_temp = session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)). \
    filter(Measurement.station == most_active_st)
query_temp[0]
# Out:
# (54.0, 85.0, 71.66378066378067)

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
data = session.query(Measurement.tobs). \
    filter(Measurement.date > yr_last).filter(Measurement.station == most_active_st).statement
temp_df = pd.read_sql_query(data, session.bind)
temp_df.head()
# Out:
#    tobs
# 0  77.0
# 1  77.0
# 2  80.0
# 3  80.0
# 4  75.0

# %%
fig, ax =plt.subplots(tight_layout = True)
ax.hist(temp_df['tobs'], bins = 12)
ax.set(xlabel='Temp', ylabel='Frequency',
       title='Temperature Count')
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Temp'), Text(0.5,1,'Temperature Count')]

# %%
# Write a function called `calc_temps` that will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
print(calc_temps(yr_last,last_dt))
# Out:
# [(58.0, 74.59058295964125, 87.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
data2 = np.ravel(calc_temps(yr_last,last_dt))
tmin = data2[0]
avg_temp = [data2[1]]
tmax = data2[2]
p2p = tmax-tmin
x_axis = np.arange(len(avg_temp))

# %%
plt.bar(x_axis, avg_temp, align = 'center', alpha = 0.5, yerr = p2p)
plt.xticks(x_axis)
plt.ylabel('Temperature')
plt.title('Trip Avg Temp')
plt.show()
plt.savefig('tripavgtemp.png')

# %%
# Calculate the rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
sel = [Measurement.station, Station.name, Measurement.tobs, (Measurement.prcp).label('Precipitation'), \
       Station.latitude, Station.longitude, Station.elevation]
tot_rainfall = session.query(*sel).filter(Measurement.station == Station.station).\
        filter(Measurement.date == yr_last).order_by("Precipitation DESC")
# Out:
# C:\Users\orv2\Anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:643: SAWarning: Can't resolve label reference 'Precipitation DESC'; converting to text() (this warning may be suppressed after 10 occurrences)
#   util.ellipses_string(element.element))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-6c613c6047ce> in <module>()
#       4 tot_rainfall = session.query(*sel).filter(Measurement.station == Station.station).        filter(Measurement.date == yr_last).order_by("Precipitation DESC")
#       5
# ----> 6 tot_rainfall[0]
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\orm\query.py in __getitem__(self, item)
#    2683                 return list(self)[-1]
#    2684             else:
# -> 2685                 return list(self[item:item + 1])[0]
#    2686
#    2687     @_generative(_no_statement_condition)
#
# IndexError: list index out of range

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
