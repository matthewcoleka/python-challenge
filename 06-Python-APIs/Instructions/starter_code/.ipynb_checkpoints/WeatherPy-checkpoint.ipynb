# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 618

# %% [markdown]
# ## Perform API Calls

# %%
#create df
weather_df = pd.DataFrame({"City":cities,
                           "Temperature":"",
                           "Humidity":"",
                           "Cloudiness":"",
                           "Wind Speed":""
})



# OpenWeatherMap API Key
api_key = api_keys.api_key

weather_df.head()
# Out:
#               City Temperature Humidity Cloudiness Wind Speed
# 0          malindi
# 1              vao
# 2         bokspits
# 3        hithadhoo
# 4  arraial do cabo

# %%
# use iterrows to iterate through pandas dataframe
for index, row in weather_df.iterrows():

    # get restaurant type from df
    cityname = row['City']

    # create url
    url = f"http://api.openweathermap.org/data/2.5/weather?q={cityname}&units=imperial&APPID=" + api_key

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {cityname}.")
    response = requests.get(url).json()
    #Grabbing data

    
    #Output results
    try:
        temp = response['main']['temp']
        humid = response['main']['humidity']
        cloud = response['clouds']['all']
        wind = response['wind']['speed']
        lat = response['coord']['lat']
        lng = response['coord']['lon']
    
        print(f"In {cityname}, the temp is {temp}F, the humidity is {humid},the cloudiness is {cloud}, and the wind speed is {wind}.")
        
        weather_df.loc[index, 'Latitude'] = lat
        weather_df.loc[index, 'Longitude'] = lng
        weather_df.loc[index, 'Temperature'] = temp
        weather_df.loc[index, 'Humidity'] = humid
        weather_df.loc[index, 'Cloudiness'] = cloud
        weather_df.loc[index, 'Wind Speed'] = wind
        
        
    except (KeyError, IndexError):
        print(f"Missing field/result... skipping. URL:{url}")
        
    print("------------")
    time.sleep(3)
# Out:
# Retrieving Results for Index 0: malindi.
# In malindi, the temp is 77.03F, the humidity is 82,the cloudiness is 80, and the wind speed is 11.65.
# ------------
# Retrieving Results for Index 1: vao.
# In vao, the temp is 45.44F, the humidity is 100,the cloudiness is 88, and the wind speed is 5.39.
# ------------
# Retrieving Results for Index 2: bokspits.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=bokspits&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 3: hithadhoo.
# In hithadhoo, the temp is 78.11F, the humidity is 100,the cloudiness is 88, and the wind speed is 17.47.
# ------------
# Retrieving Results for Index 4: arraial do cabo.
# In arraial do cabo, the temp is 73.52F, the humidity is 95,the cloudiness is 92, and the wind speed is 3.15.
# ------------
# Retrieving Results for Index 5: minna.
# In minna, the temp is 69.83F, the humidity is 98,the cloudiness is 88, and the wind speed is 5.17.
# ------------
# Retrieving Results for Index 6: hermanus.
# In hermanus, the temp is 53.45F, the humidity is 96,the cloudiness is 92, and the wind speed is 6.62.
# ------------
# Retrieving Results for Index 7: attawapiskat.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 8: solovetskiy.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=solovetskiy&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 9: punta arenas.
# In punta arenas, the temp is 37.4F, the humidity is 100,the cloudiness is 75, and the wind speed is 17.22.
# ------------
# Retrieving Results for Index 10: busselton.
# In busselton, the temp is 63.71F, the humidity is 93,the cloudiness is 12, and the wind speed is 17.13.
# ------------
# Retrieving Results for Index 11: umm lajj.
# In umm lajj, the temp is 76.4F, the humidity is 99,the cloudiness is 0, and the wind speed is 4.5.
# ------------
# Retrieving Results for Index 12: hambantota.
# In hambantota, the temp is 80.45F, the humidity is 100,the cloudiness is 68, and the wind speed is 12.1.
# ------------
# Retrieving Results for Index 13: rikitea.
# In rikitea, the temp is 70.55F, the humidity is 100,the cloudiness is 88, and the wind speed is 12.66.
# ------------
# Retrieving Results for Index 14: talara.
# In talara, the temp is 66.23F, the humidity is 86,the cloudiness is 20, and the wind speed is 6.17.
# ------------
# Retrieving Results for Index 15: adrar.
# In adrar, the temp is 77F, the humidity is 33,the cloudiness is 0, and the wind speed is 11.41.
# ------------
# Retrieving Results for Index 16: mataura.
# In mataura, the temp is 50.75F, the humidity is 73,the cloudiness is 20, and the wind speed is 14.
# ------------
# Retrieving Results for Index 17: saint george.
# In saint george, the temp is 57.2F, the humidity is 62,the cloudiness is 20, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 18: praia da vitoria.
# In praia da vitoria, the temp is 71.6F, the humidity is 83,the cloudiness is 40, and the wind speed is 19.04.
# ------------
# Retrieving Results for Index 19: ngukurr.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=ngukurr&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 20: geraldton.
# In geraldton, the temp is 33.8F, the humidity is 74,the cloudiness is 75, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 21: provideniya.
# In provideniya, the temp is 51.8F, the humidity is 87,the cloudiness is 90, and the wind speed is 8.95.
# ------------
# Retrieving Results for Index 22: hilo.
# In hilo, the temp is 77.4F, the humidity is 59,the cloudiness is 75, and the wind speed is 12.75.
# ------------
# Retrieving Results for Index 23: albany.
# In albany, the temp is 52.75F, the humidity is 86,the cloudiness is 90, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 24: cape town.
# In cape town, the temp is 55.4F, the humidity is 82,the cloudiness is 40, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 25: isangel.
# In isangel, the temp is 71.45F, the humidity is 100,the cloudiness is 100, and the wind speed is 9.31.
# ------------
# Retrieving Results for Index 26: blind river.
# In blind river, the temp is 47.75F, the humidity is 93,the cloudiness is 90, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 27: baloda bazar.
# In baloda bazar, the temp is 86.48F, the humidity is 69,the cloudiness is 8, and the wind speed is 3.6.
# ------------
# Retrieving Results for Index 28: atar.
# In atar, the temp is 76.04F, the humidity is 59,the cloudiness is 64, and the wind speed is 2.59.
# ------------
# Retrieving Results for Index 29: luderitz.
# In luderitz, the temp is 56.96F, the humidity is 75,the cloudiness is 0, and the wind speed is 21.61.
# ------------
# Retrieving Results for Index 30: andenes.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=andenes&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 31: laguna.
# In laguna, the temp is 86F, the humidity is 58,the cloudiness is 5, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 32: mount gambier.
# In mount gambier, the temp is 74.15F, the humidity is 53,the cloudiness is 64, and the wind speed is 9.08.
# ------------
# Retrieving Results for Index 33: new norfolk.
# In new norfolk, the temp is 60.8F, the humidity is 55,the cloudiness is 40, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 34: teya.
# In teya, the temp is 77F, the humidity is 94,the cloudiness is 40, and the wind speed is 5.5.
# ------------
# Retrieving Results for Index 35: bosaso.
# In bosaso, the temp is 80F, the humidity is 100,the cloudiness is 0, and the wind speed is 4.61.
# ------------
# Retrieving Results for Index 36: cidreira.
# In cidreira, the temp is 63.53F, the humidity is 100,the cloudiness is 92, and the wind speed is 13.44.
# ------------
# Retrieving Results for Index 37: yaizu.
# In yaizu, the temp is 73.43F, the humidity is 100,the cloudiness is 0, and the wind speed is 8.08.
# ------------
# Retrieving Results for Index 38: bluff.
# In bluff, the temp is 82.79F, the humidity is 23,the cloudiness is 0, and the wind speed is 12.44.
# ------------
# Retrieving Results for Index 39: mogadishu.
# In mogadishu, the temp is 77.66F, the humidity is 100,the cloudiness is 76, and the wind speed is 13.22.
# ------------
# Retrieving Results for Index 40: lompoc.
# In lompoc, the temp is 65.52F, the humidity is 80,the cloudiness is 1, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 41: san vicente.
# In san vicente, the temp is 71.6F, the humidity is 94,the cloudiness is 75, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 42: port alfred.
# In port alfred, the temp is 63.89F, the humidity is 100,the cloudiness is 64, and the wind speed is 12.77.
# ------------
# Retrieving Results for Index 43: serik.
# In serik, the temp is 64.4F, the humidity is 72,the cloudiness is 40, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 44: moroni.
# In moroni, the temp is 59.84F, the humidity is 49,the cloudiness is 68, and the wind speed is 3.94.
# ------------
# Retrieving Results for Index 45: leningradskiy.
# In leningradskiy, the temp is 41.3F, the humidity is 89,the cloudiness is 80, and the wind speed is 14.67.
# ------------
# Retrieving Results for Index 46: hobart.
# In hobart, the temp is 60.8F, the humidity is 55,the cloudiness is 40, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 47: bafoulabe.
# In bafoulabe, the temp is 75.95F, the humidity is 82,the cloudiness is 8, and the wind speed is 1.03.
# ------------
# Retrieving Results for Index 48: umzimvubu.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=umzimvubu&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 49: kapaa.
# In kapaa, the temp is 84.15F, the humidity is 79,the cloudiness is 40, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 50: fukue.
# In fukue, the temp is 71.6F, the humidity is 56,the cloudiness is 20, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 51: puerto ayora.
# In puerto ayora, the temp is 70.55F, the humidity is 100,the cloudiness is 8, and the wind speed is 11.65.
# ------------
# Retrieving Results for Index 52: carnarvon.
# In carnarvon, the temp is 52.37F, the humidity is 18,the cloudiness is 8, and the wind speed is 10.2.
# ------------
# Retrieving Results for Index 53: ushuaia.
# In ushuaia, the temp is 35.6F, the humidity is 74,the cloudiness is 40, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 54: pindi bhattian.
# In pindi bhattian, the temp is 76.67F, the humidity is 67,the cloudiness is 0, and the wind speed is 4.38.
# ------------
# Retrieving Results for Index 55: mys shmidta.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=mys shmidta&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 56: yellowknife.
# In yellowknife, the temp is 32F, the humidity is 97,the cloudiness is 40, and the wind speed is 13.87.
# ------------
# Retrieving Results for Index 57: tomatlan.
# In tomatlan, the temp is 74.78F, the humidity is 93,the cloudiness is 44, and the wind speed is 2.37.
# ------------
# Retrieving Results for Index 58: jamestown.
# In jamestown, the temp is 77.48F, the humidity is 31,the cloudiness is 76, and the wind speed is 14.67.
# ------------
# Retrieving Results for Index 59: salta.
# In salta, the temp is 59F, the humidity is 77,the cloudiness is 40, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 60: mao.
# In mao, the temp is 77.92F, the humidity is 83,the cloudiness is 75, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 61: rawannawi.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=rawannawi&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 62: mount vernon.
# In mount vernon, the temp is 59.38F, the humidity is 100,the cloudiness is 90, and the wind speed is 2.71.
# ------------
# Retrieving Results for Index 63: tuatapere.
# In tuatapere, the temp is 46.79F, the humidity is 100,the cloudiness is 12, and the wind speed is 11.54.
# ------------
# Retrieving Results for Index 64: lebu.
# In lebu, the temp is 50F, the humidity is 81,the cloudiness is 40, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 65: ranong.
# In ranong, the temp is 80.6F, the humidity is 88,the cloudiness is 75, and the wind speed is 4.5.
# ------------
# Retrieving Results for Index 66: kodiak.
# In kodiak, the temp is 60.98F, the humidity is 89,the cloudiness is 90, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 67: saldanha.
# In saldanha, the temp is 51.11F, the humidity is 60,the cloudiness is 24, and the wind speed is 10.42.
# ------------
# Retrieving Results for Index 68: kieta.
# In kieta, the temp is 82.07F, the humidity is 100,the cloudiness is 32, and the wind speed is 4.61.
# ------------
# Retrieving Results for Index 69: zhigansk.
# In zhigansk, the temp is 35.45F, the humidity is 89,the cloudiness is 88, and the wind speed is 3.71.
# ------------
# Retrieving Results for Index 70: palabuhanratu.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 71: pevek.
# In pevek, the temp is 43.37F, the humidity is 95,the cloudiness is 92, and the wind speed is 2.15.
# ------------
# Retrieving Results for Index 72: hornepayne.
# In hornepayne, the temp is 28.61F, the humidity is 93,the cloudiness is 0, and the wind speed is 4.27.
# ------------
# Retrieving Results for Index 73: porto velho.
# In porto velho, the temp is 75.2F, the humidity is 88,the cloudiness is 75, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 74: illoqqortoormiut.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 75: the valley.
# In the valley, the temp is 80.6F, the humidity is 74,the cloudiness is 20, and the wind speed is 3.38.
# ------------
# Retrieving Results for Index 76: castro.
# In castro, the temp is 43.91F, the humidity is 98,the cloudiness is 88, and the wind speed is 6.17.
# ------------
# Retrieving Results for Index 77: lukovetskiy.
# In lukovetskiy, the temp is 39.2F, the humidity is 100,the cloudiness is 40, and the wind speed is 4.47.
# ------------
# Retrieving Results for Index 78: birao.
# In birao, the temp is 69.47F, the humidity is 90,the cloudiness is 0, and the wind speed is 2.82.
# ------------
# Retrieving Results for Index 79: bredasdorp.
# In bredasdorp, the temp is 55.4F, the humidity is 82,the cloudiness is 36, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 80: bjornevatn.
# In bjornevatn, the temp is 33.8F, the humidity is 74,the cloudiness is 68, and the wind speed is 26.4.
# ------------
# Retrieving Results for Index 81: tiksi.
# In tiksi, the temp is 28.79F, the humidity is 100,the cloudiness is 64, and the wind speed is 8.08.
# ------------
# Retrieving Results for Index 82: saskylakh.
# In saskylakh, the temp is 30.05F, the humidity is 99,the cloudiness is 92, and the wind speed is 6.17.
# ------------
# Retrieving Results for Index 83: urumqi.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=urumqi&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 84: chokurdakh.
# In chokurdakh, the temp is 36.17F, the humidity is 95,the cloudiness is 76, and the wind speed is 14.45.
# ------------
# Retrieving Results for Index 85: nuqui.
# In nuqui, the temp is 76.94F, the humidity is 100,the cloudiness is 92, and the wind speed is 5.17.
# ------------
# Retrieving Results for Index 86: belushya guba.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=belushya guba&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 87: samusu.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=samusu&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 88: kalaleh.
# In kalaleh, the temp is 58.85F, the humidity is 83,the cloudiness is 0, and the wind speed is 2.37.
# ------------
# Retrieving Results for Index 89: anan.
# In anan, the temp is 69.8F, the humidity is 68,the cloudiness is 75, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 90: killybegs.
# In killybegs, the temp is 54.17F, the humidity is 100,the cloudiness is 92, and the wind speed is 18.92.
# ------------
# Retrieving Results for Index 91: miandrivazo.
# In miandrivazo, the temp is 57.5F, the humidity is 81,the cloudiness is 0, and the wind speed is 2.59.
# ------------
# Retrieving Results for Index 92: guerrero negro.
# In guerrero negro, the temp is 72.71F, the humidity is 96,the cloudiness is 92, and the wind speed is 19.71.
# ------------
# Retrieving Results for Index 93: khatanga.
# In khatanga, the temp is 34.91F, the humidity is 100,the cloudiness is 64, and the wind speed is 4.5.
# ------------
# Retrieving Results for Index 94: sorong.
# In sorong, the temp is 81.62F, the humidity is 100,the cloudiness is 64, and the wind speed is 6.29.
# ------------
# Retrieving Results for Index 95: bull savanna.
# In bull savanna, the temp is 74.78F, the humidity is 87,the cloudiness is 44, and the wind speed is 4.38.
# ------------
# Retrieving Results for Index 96: cauquenes.
# In cauquenes, the temp is 46.25F, the humidity is 76,the cloudiness is 0, and the wind speed is 12.44.
# ------------
# Retrieving Results for Index 97: avarua.
# In avarua, the temp is 75.2F, the humidity is 50,the cloudiness is 40, and the wind speed is 17.22.
# ------------
# Retrieving Results for Index 98: akyab.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=akyab&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 99: anju.
# In anju, the temp is 64.07F, the humidity is 78,the cloudiness is 0, and the wind speed is 4.72.
# ------------
# Retrieving Results for Index 100: minas novas.
# In minas novas, the temp is 74.51F, the humidity is 62,the cloudiness is 32, and the wind speed is 11.99.
# ------------
# Retrieving Results for Index 101: butaritari.
# In butaritari, the temp is 84.5F, the humidity is 100,the cloudiness is 76, and the wind speed is 3.71.
# ------------
# Retrieving Results for Index 102: kurashiki.
# In kurashiki, the temp is 68.13F, the humidity is 63,the cloudiness is 40, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 103: kaitangata.
# In kaitangata, the temp is 48.23F, the humidity is 79,the cloudiness is 32, and the wind speed is 15.46.
# ------------
# Retrieving Results for Index 104: cherskiy.
# In cherskiy, the temp is 44.27F, the humidity is 68,the cloudiness is 56, and the wind speed is 2.71.
# ------------
# Retrieving Results for Index 105: hofn.
# In hofn, the temp is 40.22F, the humidity is 100,the cloudiness is 0, and the wind speed is 14.79.
# ------------
# Retrieving Results for Index 106: milingimbi.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=milingimbi&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 107: baoro.
# In baoro, the temp is 66.41F, the humidity is 99,the cloudiness is 88, and the wind speed is 4.38.
# ------------
# Retrieving Results for Index 108: krasnovishersk.
# In krasnovishersk, the temp is 42.92F, the humidity is 95,the cloudiness is 92, and the wind speed is 10.98.
# ------------
# Retrieving Results for Index 109: grand gaube.
# In grand gaube, the temp is 71.6F, the humidity is 83,the cloudiness is 75, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 110: havre-saint-pierre.
# In havre-saint-pierre, the temp is 35.6F, the humidity is 93,the cloudiness is 40, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 111: taolanaro.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 112: bengkulu.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=bengkulu&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 113: mahebourg.
# In mahebourg, the temp is 71.6F, the humidity is 83,the cloudiness is 75, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 114: tezu.
# In tezu, the temp is 69.83F, the humidity is 72,the cloudiness is 20, and the wind speed is 1.14.
# ------------
# Retrieving Results for Index 115: vaini.
# In vaini, the temp is 75.59F, the humidity is 87,the cloudiness is 0, and the wind speed is 3.6.
# ------------
# Retrieving Results for Index 116: winburg.
# In winburg, the temp is 49.76F, the humidity is 56,the cloudiness is 0, and the wind speed is 7.74.
# ------------
# Retrieving Results for Index 117: lindi.
# In lindi, the temp is 67.4F, the humidity is 97,the cloudiness is 88, and the wind speed is 2.59.
# ------------
# Retrieving Results for Index 118: barrow.
# In barrow, the temp is 38.33F, the humidity is 46,the cloudiness is 0, and the wind speed is 11.99.
# ------------
# Retrieving Results for Index 119: namibe.
# In namibe, the temp is 66.14F, the humidity is 100,the cloudiness is 56, and the wind speed is 5.39.
# ------------
# Retrieving Results for Index 120: basmat.
# In basmat, the temp is 81.71F, the humidity is 72,the cloudiness is 0, and the wind speed is 4.61.
# ------------
# Retrieving Results for Index 121: basingstoke.
# In basingstoke, the temp is 50.41F, the humidity is 71,the cloudiness is 75, and the wind speed is 14.99.
# ------------
# Retrieving Results for Index 122: buala.
# In buala, the temp is 84.14F, the humidity is 85,the cloudiness is 32, and the wind speed is 4.16.
# ------------
# Retrieving Results for Index 123: tsihombe.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=tsihombe&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 124: alofi.
# In alofi, the temp is 77F, the humidity is 61,the cloudiness is 75, and the wind speed is 20.8.
# ------------
# Retrieving Results for Index 125: east london.
# In east london, the temp is 68.57F, the humidity is 100,the cloudiness is 24, and the wind speed is 13.
# ------------
# Retrieving Results for Index 126: prachuap khiri khan.
# In prachuap khiri khan, the temp is 79.37F, the humidity is 88,the cloudiness is 88, and the wind speed is 3.38.
# ------------
# Retrieving Results for Index 127: sarahan.
# In sarahan, the temp is 25.28F, the humidity is 71,the cloudiness is 0, and the wind speed is 1.14.
# ------------
# Retrieving Results for Index 128: fenoarivo.
# In fenoarivo, the temp is 53.6F, the humidity is 87,the cloudiness is 20, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 129: souillac.
# In souillac, the temp is 44.6F, the humidity is 70,the cloudiness is 0, and the wind speed is 3.71.
# ------------
# Retrieving Results for Index 130: nizhneyansk.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 131: cavalcante.
# In cavalcante, the temp is 65.33F, the humidity is 94,the cloudiness is 44, and the wind speed is 2.26.
# ------------
# Retrieving Results for Index 132: atuona.
# In atuona, the temp is 79.73F, the humidity is 100,the cloudiness is 0, and the wind speed is 12.44.
# ------------
# Retrieving Results for Index 133: tessalit.
# In tessalit, the temp is 80F, the humidity is 34,the cloudiness is 36, and the wind speed is 9.98.
# ------------
# Retrieving Results for Index 134: marfino.
# In marfino, the temp is 41.58F, the humidity is 75,the cloudiness is 0, and the wind speed is 4.47.
# ------------
# Retrieving Results for Index 135: bani.
# In bani, the temp is 80.36F, the humidity is 98,the cloudiness is 76, and the wind speed is 2.71.
# ------------
# Retrieving Results for Index 136: novozavidovskiy.
# In novozavidovskiy, the temp is 39.86F, the humidity is 87,the cloudiness is 0, and the wind speed is 11.43.
# ------------
# Retrieving Results for Index 137: makakilo city.
# In makakilo city, the temp is 84.69F, the humidity is 67,the cloudiness is 1, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 138: codrington.
# In codrington, the temp is 69.2F, the humidity is 66,the cloudiness is 24, and the wind speed is 6.17.
# ------------
# Retrieving Results for Index 139: tasiilaq.
# In tasiilaq, the temp is 30.2F, the humidity is 58,the cloudiness is 0, and the wind speed is 1.12.
# ------------
# Retrieving Results for Index 140: christchurch.
# In christchurch, the temp is 60.8F, the humidity is 67,the cloudiness is 68, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 141: saint-joseph.
# In saint-joseph, the temp is 56.66F, the humidity is 76,the cloudiness is 0, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 142: cefa.
# In cefa, the temp is 51.8F, the humidity is 81,the cloudiness is 0, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 143: kruisfontein.
# In kruisfontein, the temp is 60.2F, the humidity is 92,the cloudiness is 0, and the wind speed is 13.78.
# ------------
# Retrieving Results for Index 144: kahului.
# In kahului, the temp is 84.58F, the humidity is 59,the cloudiness is 40, and the wind speed is 16.11.
# ------------
# Retrieving Results for Index 145: bethel.
# In bethel, the temp is 51.98F, the humidity is 74,the cloudiness is 90, and the wind speed is 12.75.
# ------------
# Retrieving Results for Index 146: bridlington.
# In bridlington, the temp is 51.33F, the humidity is 81,the cloudiness is 92, and the wind speed is 23.04.
# ------------
# Retrieving Results for Index 147: matamoros.
# In matamoros, the temp is 81.79F, the humidity is 87,the cloudiness is 1, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 148: bac lieu.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=bac lieu&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 149: bathsheba.
# In bathsheba, the temp is 80.6F, the humidity is 78,the cloudiness is 40, and the wind speed is 11.41.
# ------------
# Retrieving Results for Index 150: grenaa.
# In grenaa, the temp is 44.6F, the humidity is 93,the cloudiness is 76, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 151: havoysund.
# In havoysund, the temp is 35.6F, the humidity is 64,the cloudiness is 75, and the wind speed is 16.11.
# ------------
# Retrieving Results for Index 152: qaanaaq.
# In qaanaaq, the temp is 15.74F, the humidity is 100,the cloudiness is 0, and the wind speed is 13.78.
# ------------
# Retrieving Results for Index 153: margate.
# In margate, the temp is 60.8F, the humidity is 55,the cloudiness is 40, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 154: markova.
# In markova, the temp is 50F, the humidity is 61,the cloudiness is 0, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 155: baykit.
# In baykit, the temp is 38.96F, the humidity is 85,the cloudiness is 32, and the wind speed is 13.67.
# ------------
# Retrieving Results for Index 156: kindu.
# In kindu, the temp is 71.09F, the humidity is 98,the cloudiness is 88, and the wind speed is 2.15.
# ------------
# Retrieving Results for Index 157: hihifo.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=hihifo&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 158: georgetown.
# In georgetown, the temp is 77.66F, the humidity is 87,the cloudiness is 0, and the wind speed is 6.29.
# ------------
# Retrieving Results for Index 159: iqaluit.
# In iqaluit, the temp is 28.4F, the humidity is 74,the cloudiness is 90, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 160: bilma.
# In bilma, the temp is 72.35F, the humidity is 27,the cloudiness is 0, and the wind speed is 4.5.
# ------------
# Retrieving Results for Index 161: meulaboh.
# In meulaboh, the temp is 80F, the humidity is 100,the cloudiness is 88, and the wind speed is 2.48.
# ------------
# Retrieving Results for Index 162: palafrugell.
# In palafrugell, the temp is 42.8F, the humidity is 81,the cloudiness is 20, and the wind speed is 23.17.
# ------------
# Retrieving Results for Index 163: cleveland.
# In cleveland, the temp is 66.76F, the humidity is 89,the cloudiness is 1, and the wind speed is 8.63.
# ------------
# Retrieving Results for Index 164: cabo san lucas.
# In cabo san lucas, the temp is 83.39F, the humidity is 78,the cloudiness is 75, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 165: zhoucheng.
# In zhoucheng, the temp is 73.88F, the humidity is 59,the cloudiness is 24, and the wind speed is 4.16.
# ------------
# Retrieving Results for Index 166: port elizabeth.
# In port elizabeth, the temp is 70.77F, the humidity is 81,the cloudiness is 1, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 167: mar del plata.
# In mar del plata, the temp is 45.71F, the humidity is 52,the cloudiness is 80, and the wind speed is 14.56.
# ------------
# Retrieving Results for Index 168: la belleza.
# In la belleza, the temp is 61.91F, the humidity is 100,the cloudiness is 92, and the wind speed is 2.93.
# ------------
# Retrieving Results for Index 169: porto novo.
# In porto novo, the temp is 66.2F, the humidity is 93,the cloudiness is 0, and the wind speed is 2.59.
# ------------
# Retrieving Results for Index 170: binga.
# In binga, the temp is 67.76F, the humidity is 76,the cloudiness is 0, and the wind speed is 5.95.
# ------------
# Retrieving Results for Index 171: dikson.
# In dikson, the temp is 37.88F, the humidity is 100,the cloudiness is 56, and the wind speed is 18.92.
# ------------
# Retrieving Results for Index 172: te anau.
# In te anau, the temp is 43.19F, the humidity is 100,the cloudiness is 92, and the wind speed is 4.05.
# ------------
# Retrieving Results for Index 173: nara.
# In nara, the temp is 72.03F, the humidity is 53,the cloudiness is 40, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 174: sentyabrskiy.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 175: tuktoyaktuk.
# In tuktoyaktuk, the temp is 26.6F, the humidity is 92,the cloudiness is 75, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 176: altagracia de orituco.
# In altagracia de orituco, the temp is 79.37F, the humidity is 68,the cloudiness is 12, and the wind speed is 10.42.
# ------------
# Retrieving Results for Index 177: kattivakkam.
# In kattivakkam, the temp is 82.4F, the humidity is 88,the cloudiness is 40, and the wind speed is 1.36.
# ------------
# Retrieving Results for Index 178: bodden town.
# In bodden town, the temp is 82.4F, the humidity is 88,the cloudiness is 20, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 179: murgab.
# In murgab, the temp is 59F, the humidity is 58,the cloudiness is 0, and the wind speed is 2.59.
# ------------
# Retrieving Results for Index 180: vaitupu.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=vaitupu&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 181: nuevo progreso.
# In nuevo progreso, the temp is 81.99F, the humidity is 88,the cloudiness is 1, and the wind speed is 7.74.
# ------------
# Retrieving Results for Index 182: changde.
# In changde, the temp is 73.25F, the humidity is 72,the cloudiness is 32, and the wind speed is 4.38.
# ------------
# Retrieving Results for Index 183: samarai.
# In samarai, the temp is 76.13F, the humidity is 100,the cloudiness is 92, and the wind speed is 14.67.
# ------------
# Retrieving Results for Index 184: carikar.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=carikar&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 185: wasilla.
# In wasilla, the temp is 50.58F, the humidity is 74,the cloudiness is 1, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 186: savonlinna.
# In savonlinna, the temp is 41F, the humidity is 100,the cloudiness is 75, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 187: ozernovskiy.
# In ozernovskiy, the temp is 44.99F, the humidity is 91,the cloudiness is 92, and the wind speed is 16.13.
# ------------
# Retrieving Results for Index 188: beringovskiy.
# In beringovskiy, the temp is 46.25F, the humidity is 97,the cloudiness is 20, and the wind speed is 4.94.
# ------------
# Retrieving Results for Index 189: saint anthony.
# In saint anthony, the temp is 61.63F, the humidity is 32,the cloudiness is 1, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 190: eydhafushi.
# In eydhafushi, the temp is 81.89F, the humidity is 100,the cloudiness is 88, and the wind speed is 20.27.
# ------------
# Retrieving Results for Index 191: ribeira grande.
# In ribeira grande, the temp is 73.7F, the humidity is 95,the cloudiness is 56, and the wind speed is 19.93.
# ------------
# Retrieving Results for Index 192: ikongo.
# In ikongo, the temp is 55.25F, the humidity is 97,the cloudiness is 88, and the wind speed is 0.81.
# ------------
# Retrieving Results for Index 193: manavgat.
# In manavgat, the temp is 64.4F, the humidity is 72,the cloudiness is 40, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 194: cairns.
# In cairns, the temp is 82.4F, the humidity is 45,the cloudiness is 20, and the wind speed is 26.4.
# ------------
# Retrieving Results for Index 195: chifeng.
# In chifeng, the temp is 61.37F, the humidity is 46,the cloudiness is 0, and the wind speed is 6.73.
# ------------
# Retrieving Results for Index 196: alice springs.
# In alice springs, the temp is 86F, the humidity is 12,the cloudiness is 0, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 197: thompson.
# In thompson, the temp is 33.8F, the humidity is 64,the cloudiness is 90, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 198: vardo.
# In vardo, the temp is 71.96F, the humidity is 73,the cloudiness is 1, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 199: aklavik.
# In aklavik, the temp is 37.4F, the humidity is 59,the cloudiness is 40, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 200: vostok.
# In vostok, the temp is 50.48F, the humidity is 59,the cloudiness is 0, and the wind speed is 4.61.
# ------------
# Retrieving Results for Index 201: narsaq.
# In narsaq, the temp is 33.8F, the humidity is 47,the cloudiness is 32, and the wind speed is 20.8.
# ------------
# Retrieving Results for Index 202: bambous virieux.
# In bambous virieux, the temp is 71.6F, the humidity is 83,the cloudiness is 75, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 203: bonthe.
# In bonthe, the temp is 73.43F, the humidity is 100,the cloudiness is 88, and the wind speed is 4.16.
# ------------
# Retrieving Results for Index 204: sorland.
# In sorland, the temp is 47.15F, the humidity is 100,the cloudiness is 92, and the wind speed is 3.94.
# ------------
# Retrieving Results for Index 205: pangnirtung.
# In pangnirtung, the temp is 27.17F, the humidity is 93,the cloudiness is 80, and the wind speed is 11.77.
# ------------
# Retrieving Results for Index 206: sumbawa.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=sumbawa&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 207: barentsburg.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 208: dharchula.
# In dharchula, the temp is 51.47F, the humidity is 61,the cloudiness is 0, and the wind speed is 1.7.
# ------------
# Retrieving Results for Index 209: sao filipe.
# In sao filipe, the temp is 77.21F, the humidity is 100,the cloudiness is 64, and the wind speed is 12.77.
# ------------
# Retrieving Results for Index 210: tocache.
# In tocache, the temp is 57.32F, the humidity is 89,the cloudiness is 64, and the wind speed is 0.92.
# ------------
# Retrieving Results for Index 211: rocha.
# In rocha, the temp is 39.32F, the humidity is 85,the cloudiness is 0, and the wind speed is 3.94.
# ------------
# Retrieving Results for Index 212: nizhniy odes.
# In nizhniy odes, the temp is 42.2F, the humidity is 94,the cloudiness is 88, and the wind speed is 8.19.
# ------------
# Retrieving Results for Index 213: statesboro.
# In statesboro, the temp is 73.22F, the humidity is 90,the cloudiness is 1, and the wind speed is 5.61.
# ------------
# Retrieving Results for Index 214: college.
# In college, the temp is 66.88F, the humidity is 6,the cloudiness is 1, and the wind speed is 11.41.
# ------------
# Retrieving Results for Index 215: grand river south east.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=grand river south east&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 216: tarko-sale.
# In tarko-sale, the temp is 33.65F, the humidity is 92,the cloudiness is 92, and the wind speed is 10.54.
# ------------
# Retrieving Results for Index 217: surgut.
# In surgut, the temp is 35.6F, the humidity is 100,the cloudiness is 20, and the wind speed is 8.95.
# ------------
# Retrieving Results for Index 218: lasem.
# In lasem, the temp is 84.2F, the humidity is 66,the cloudiness is 8, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 219: xingyi.
# In xingyi, the temp is 60.02F, the humidity is 86,the cloudiness is 88, and the wind speed is 3.6.
# ------------
# Retrieving Results for Index 220: severo-kurilsk.
# In severo-kurilsk, the temp is 47.15F, the humidity is 96,the cloudiness is 48, and the wind speed is 16.02.
# ------------
# Retrieving Results for Index 221: narasannapeta.
# In narasannapeta, the temp is 84.05F, the humidity is 83,the cloudiness is 0, and the wind speed is 4.16.
# ------------
# Retrieving Results for Index 222: lavrentiya.
# In lavrentiya, the temp is 45.62F, the humidity is 93,the cloudiness is 92, and the wind speed is 17.36.
# ------------
# Retrieving Results for Index 223: terrace.
# In terrace, the temp is 51.8F, the humidity is 32,the cloudiness is 75, and the wind speed is 14.99.
# ------------
# Retrieving Results for Index 224: saleaula.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=saleaula&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 225: camacha.
# In camacha, the temp is 70.81F, the humidity is 73,the cloudiness is 75, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 226: pitimbu.
# In pitimbu, the temp is 73.4F, the humidity is 78,the cloudiness is 20, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 227: ereymentau.
# In ereymentau, the temp is 42.47F, the humidity is 92,the cloudiness is 0, and the wind speed is 6.17.
# ------------
# Retrieving Results for Index 228: puerto princesa.
# In puerto princesa, the temp is 86F, the humidity is 70,the cloudiness is 20, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 229: tual.
# In tual, the temp is 81.53F, the humidity is 95,the cloudiness is 44, and the wind speed is 14.79.
# ------------
# Retrieving Results for Index 230: padang.
# In padang, the temp is 79.91F, the humidity is 100,the cloudiness is 92, and the wind speed is 8.63.
# ------------
# Retrieving Results for Index 231: pacific grove.
# In pacific grove, the temp is 67.48F, the humidity is 56,the cloudiness is 1, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 232: ryabovo.
# In ryabovo, the temp is 49.58F, the humidity is 99,the cloudiness is 92, and the wind speed is 7.29.
# ------------
# Retrieving Results for Index 233: chumikan.
# In chumikan, the temp is 52.82F, the humidity is 62,the cloudiness is 32, and the wind speed is 6.06.
# ------------
# Retrieving Results for Index 234: xichang.
# In xichang, the temp is 48.77F, the humidity is 100,the cloudiness is 92, and the wind speed is 2.04.
# ------------
# Retrieving Results for Index 235: along.
# In along, the temp is 68.48F, the humidity is 76,the cloudiness is 76, and the wind speed is 1.81.
# ------------
# Retrieving Results for Index 236: zhanatas.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=zhanatas&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 237: biograd na moru.
# In biograd na moru, the temp is 59F, the humidity is 67,the cloudiness is 40, and the wind speed is 12.75.
# ------------
# Retrieving Results for Index 238: khandyga.
# In khandyga, the temp is 35.9F, the humidity is 60,the cloudiness is 56, and the wind speed is 1.81.
# ------------
# Retrieving Results for Index 239: ladario.
# In ladario, the temp is 55.43F, the humidity is 47,the cloudiness is 64, and the wind speed is 8.41.
# ------------
# Retrieving Results for Index 240: torbay.
# In torbay, the temp is 48.2F, the humidity is 87,the cloudiness is 75, and the wind speed is 12.75.
# ------------
# Retrieving Results for Index 241: clonakilty.
# In clonakilty, the temp is 57.2F, the humidity is 100,the cloudiness is 75, and the wind speed is 11.41.
# ------------
# Retrieving Results for Index 242: longyearbyen.
# In longyearbyen, the temp is 28.4F, the humidity is 74,the cloudiness is 75, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 243: abeche.
# In abeche, the temp is 78.2F, the humidity is 48,the cloudiness is 88, and the wind speed is 8.52.
# ------------
# Retrieving Results for Index 244: trairi.
# In trairi, the temp is 78.83F, the humidity is 100,the cloudiness is 32, and the wind speed is 21.39.
# ------------
# Retrieving Results for Index 245: fairbanks.
# In fairbanks, the temp is 66.88F, the humidity is 6,the cloudiness is 1, and the wind speed is 11.41.
# ------------
# Retrieving Results for Index 246: normandin.
# In normandin, the temp is 33.8F, the humidity is 86,the cloudiness is 75, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 247: cagayan de tawi-tawi.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=cagayan de tawi-tawi&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 248: mount isa.
# In mount isa, the temp is 87.8F, the humidity is 23,the cloudiness is 32, and the wind speed is 17.22.
# ------------
# Retrieving Results for Index 249: koulikoro.
# In koulikoro, the temp is 73.4F, the humidity is 94,the cloudiness is 20, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 250: richards bay.
# In richards bay, the temp is 65.42F, the humidity is 75,the cloudiness is 0, and the wind speed is 5.95.
# ------------
# Retrieving Results for Index 251: smithers.
# In smithers, the temp is 41F, the humidity is 52,the cloudiness is 90, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 252: lugovoy.
# In lugovoy, the temp is 39.86F, the humidity is 90,the cloudiness is 88, and the wind speed is 9.64.
# ------------
# Retrieving Results for Index 253: poum.
# In poum, the temp is 36.53F, the humidity is 87,the cloudiness is 0, and the wind speed is 1.7.
# ------------
# Retrieving Results for Index 254: tilichiki.
# In tilichiki, the temp is 43.91F, the humidity is 96,the cloudiness is 92, and the wind speed is 15.35.
# ------------
# Retrieving Results for Index 255: merauke.
# In merauke, the temp is 78.38F, the humidity is 94,the cloudiness is 88, and the wind speed is 15.57.
# ------------
# Retrieving Results for Index 256: katsuura.
# In katsuura, the temp is 69.8F, the humidity is 68,the cloudiness is 75, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 257: marcona.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=marcona&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 258: panyutyne.
# In panyutyne, the temp is 55.43F, the humidity is 82,the cloudiness is 92, and the wind speed is 7.52.
# ------------
# Retrieving Results for Index 259: aden.
# In aden, the temp is 81.44F, the humidity is 100,the cloudiness is 0, and the wind speed is 14.67.
# ------------
# Retrieving Results for Index 260: airai.
# In airai, the temp is 75.32F, the humidity is 70,the cloudiness is 44, and the wind speed is 1.92.
# ------------
# Retrieving Results for Index 261: hami.
# In hami, the temp is 62.27F, the humidity is 40,the cloudiness is 0, and the wind speed is 8.86.
# ------------
# Retrieving Results for Index 262: norman wells.
# In norman wells, the temp is 33.8F, the humidity is 74,the cloudiness is 75, and the wind speed is 12.75.
# ------------
# Retrieving Results for Index 263: kavieng.
# In kavieng, the temp is 84.23F, the humidity is 100,the cloudiness is 48, and the wind speed is 6.17.
# ------------
# Retrieving Results for Index 264: luganville.
# In luganville, the temp is 76.58F, the humidity is 100,the cloudiness is 48, and the wind speed is 8.19.
# ------------
# Retrieving Results for Index 265: gizo.
# In gizo, the temp is 78.8F, the humidity is 83,the cloudiness is 0, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 266: nikolskoye.
# In nikolskoye, the temp is 44.6F, the humidity is 81,the cloudiness is 0, and the wind speed is 8.95.
# ------------
# Retrieving Results for Index 267: harbour breton.
# In harbour breton, the temp is 47.6F, the humidity is 100,the cloudiness is 0, and the wind speed is 16.02.
# ------------
# Retrieving Results for Index 268: litoral del san juan.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=litoral del san juan&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 269: ancud.
# In ancud, the temp is 43.73F, the humidity is 94,the cloudiness is 68, and the wind speed is 5.73.
# ------------
# Retrieving Results for Index 270: manacapuru.
# In manacapuru, the temp is 83.87F, the humidity is 48,the cloudiness is 0, and the wind speed is 7.18.
# ------------
# Retrieving Results for Index 271: santa maria.
# In santa maria, the temp is 60.8F, the humidity is 93,the cloudiness is 90, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 272: buarcos.
# In buarcos, the temp is 55.4F, the humidity is 87,the cloudiness is 0, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 273: san patricio.
# In san patricio, the temp is 67.13F, the humidity is 98,the cloudiness is 92, and the wind speed is 8.41.
# ------------
# Retrieving Results for Index 274: carmelo.
# In carmelo, the temp is 50.97F, the humidity is 61,the cloudiness is 0, and the wind speed is 8.08.
# ------------
# Retrieving Results for Index 275: dukat.
# In dukat, the temp is 42.2F, the humidity is 88,the cloudiness is 8, and the wind speed is 1.81.
# ------------
# Retrieving Results for Index 276: pelotas.
# In pelotas, the temp is 58.13F, the humidity is 98,the cloudiness is 32, and the wind speed is 15.79.
# ------------
# Retrieving Results for Index 277: lorengau.
# In lorengau, the temp is 84.41F, the humidity is 100,the cloudiness is 36, and the wind speed is 6.73.
# ------------
# Retrieving Results for Index 278: abu samrah.
# In abu samrah, the temp is 61.37F, the humidity is 90,the cloudiness is 12, and the wind speed is 2.93.
# ------------
# Retrieving Results for Index 279: roma.
# In roma, the temp is 66.2F, the humidity is 55,the cloudiness is 40, and the wind speed is 11.41.
# ------------
# Retrieving Results for Index 280: morant bay.
# In morant bay, the temp is 80.81F, the humidity is 100,the cloudiness is 92, and the wind speed is 8.08.
# ------------
# Retrieving Results for Index 281: ugoofaaru.
# In ugoofaaru, the temp is 81.89F, the humidity is 100,the cloudiness is 88, and the wind speed is 20.27.
# ------------
# Retrieving Results for Index 282: maniitsoq.
# In maniitsoq, the temp is 34.28F, the humidity is 100,the cloudiness is 88, and the wind speed is 11.65.
# ------------
# Retrieving Results for Index 283: lac-megantic.
# In lac-megantic, the temp is 38.44F, the humidity is 93,the cloudiness is 75, and the wind speed is 2.93.
# ------------
# Retrieving Results for Index 284: biltine.
# In biltine, the temp is 84.5F, the humidity is 33,the cloudiness is 92, and the wind speed is 7.29.
# ------------
# Retrieving Results for Index 285: yerbogachen.
# In yerbogachen, the temp is 44.45F, the humidity is 60,the cloudiness is 56, and the wind speed is 7.29.
# ------------
# Retrieving Results for Index 286: kyzyl-suu.
# In kyzyl-suu, the temp is 51.11F, the humidity is 100,the cloudiness is 0, and the wind speed is 3.94.
# ------------
# Retrieving Results for Index 287: henties bay.
# In henties bay, the temp is 57.41F, the humidity is 95,the cloudiness is 0, and the wind speed is 2.04.
# ------------
# Retrieving Results for Index 288: mount darwin.
# In mount darwin, the temp is 53.09F, the humidity is 89,the cloudiness is 0, and the wind speed is 3.94.
# ------------
# Retrieving Results for Index 289: hobyo.
# In hobyo, the temp is 74.78F, the humidity is 94,the cloudiness is 68, and the wind speed is 13.
# ------------
# Retrieving Results for Index 290: berezniki.
# In berezniki, the temp is 44.18F, the humidity is 96,the cloudiness is 92, and the wind speed is 11.32.
# ------------
# ...
# In sarkand, the temp is 68.75F, the humidity is 25,the cloudiness is 48, and the wind speed is 8.3.
# ------------
# Retrieving Results for Index 521: grafton.
# In grafton, the temp is 70.37F, the humidity is 60,the cloudiness is 0, and the wind speed is 4.5.
# ------------
# Retrieving Results for Index 522: singarayakonda.
# In singarayakonda, the temp is 81.53F, the humidity is 88,the cloudiness is 76, and the wind speed is 1.7.
# ------------
# Retrieving Results for Index 523: mnogovershinnyy.
# In mnogovershinnyy, the temp is 47.78F, the humidity is 54,the cloudiness is 36, and the wind speed is 6.62.
# ------------
# Retrieving Results for Index 524: payo.
# In payo, the temp is 91.07F, the humidity is 47,the cloudiness is 0, and the wind speed is 7.85.
# ------------
# Retrieving Results for Index 525: vila franca do campo.
# In vila franca do campo, the temp is 71.6F, the humidity is 78,the cloudiness is 75, and the wind speed is 13.87.
# ------------
# Retrieving Results for Index 526: coquimbo.
# In coquimbo, the temp is 53.6F, the humidity is 81,the cloudiness is 0, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 527: grindavik.
# In grindavik, the temp is 42.08F, the humidity is 75,the cloudiness is 75, and the wind speed is 32.21.
# ------------
# Retrieving Results for Index 528: tabiauea.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=tabiauea&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 529: tecoanapa.
# In tecoanapa, the temp is 82.4F, the humidity is 83,the cloudiness is 75, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 530: flinders.
# In flinders, the temp is 71.6F, the humidity is 49,the cloudiness is 0, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 531: araguacu.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=araguacu&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 532: bulgan.
# In bulgan, the temp is 59.12F, the humidity is 49,the cloudiness is 0, and the wind speed is 4.16.
# ------------
# Retrieving Results for Index 533: bagdarin.
# In bagdarin, the temp is 48.23F, the humidity is 36,the cloudiness is 20, and the wind speed is 3.38.
# ------------
# Retrieving Results for Index 534: gopalur.
# In gopalur, the temp is 77.75F, the humidity is 93,the cloudiness is 0, and the wind speed is 4.61.
# ------------
# Retrieving Results for Index 535: ondjiva.
# In ondjiva, the temp is 70.46F, the humidity is 32,the cloudiness is 0, and the wind speed is 11.88.
# ------------
# Retrieving Results for Index 536: opuwo.
# In opuwo, the temp is 68.93F, the humidity is 30,the cloudiness is 8, and the wind speed is 9.42.
# ------------
# Retrieving Results for Index 537: petropavlovsk-kamchatskiy.
# In petropavlovsk-kamchatskiy, the temp is 55.4F, the humidity is 80,the cloudiness is 0, and the wind speed is 17.9.
# ------------
# Retrieving Results for Index 538: gijon.
# In gijon, the temp is 53.6F, the humidity is 81,the cloudiness is 20, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 539: doaba.
# In doaba, the temp is 62.81F, the humidity is 78,the cloudiness is 0, and the wind speed is 2.37.
# ------------
# Retrieving Results for Index 540: ponta do sol.
# In ponta do sol, the temp is 64.7F, the humidity is 95,the cloudiness is 88, and the wind speed is 2.71.
# ------------
# Retrieving Results for Index 541: garissa.
# In garissa, the temp is 70.1F, the humidity is 91,the cloudiness is 76, and the wind speed is 7.85.
# ------------
# Retrieving Results for Index 542: caravelas.
# In caravelas, the temp is 76.94F, the humidity is 100,the cloudiness is 92, and the wind speed is 17.58.
# ------------
# Retrieving Results for Index 543: marsala.
# In marsala, the temp is 73.4F, the humidity is 60,the cloudiness is 40, and the wind speed is 11.41.
# ------------
# Retrieving Results for Index 544: uige.
# In uige, the temp is 64.7F, the humidity is 98,the cloudiness is 92, and the wind speed is 1.7.
# ------------
# Retrieving Results for Index 545: taganak.
# In taganak, the temp is 87.8F, the humidity is 74,the cloudiness is 75, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 546: rodas.
# In rodas, the temp is 77.05F, the humidity is 88,the cloudiness is 20, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 547: nanzhang.
# In nanzhang, the temp is 67.67F, the humidity is 43,the cloudiness is 76, and the wind speed is 3.15.
# ------------
# Retrieving Results for Index 548: maarianhamina.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=maarianhamina&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 549: north bend.
# In north bend, the temp is 59F, the humidity is 93,the cloudiness is 90, and the wind speed is 2.71.
# ------------
# Retrieving Results for Index 550: batemans bay.
# In batemans bay, the temp is 67.22F, the humidity is 66,the cloudiness is 88, and the wind speed is 4.16.
# ------------
# Retrieving Results for Index 551: faanui.
# In faanui, the temp is 77.03F, the humidity is 100,the cloudiness is 64, and the wind speed is 15.57.
# ------------
# Retrieving Results for Index 552: pokoynoye.
# In pokoynoye, the temp is 60.11F, the humidity is 86,the cloudiness is 36, and the wind speed is 13.89.
# ------------
# Retrieving Results for Index 553: lianran.
# In lianran, the temp is 51.8F, the humidity is 100,the cloudiness is 90, and the wind speed is 8.95.
# ------------
# Retrieving Results for Index 554: oyem.
# In oyem, the temp is 68.75F, the humidity is 99,the cloudiness is 92, and the wind speed is 2.26.
# ------------
# Retrieving Results for Index 555: wembley.
# In wembley, the temp is 50.2F, the humidity is 71,the cloudiness is 75, and the wind speed is 9.17.
# ------------
# Retrieving Results for Index 556: juneau.
# In juneau, the temp is 57.02F, the humidity is 8,the cloudiness is 20, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 557: guatire.
# In guatire, the temp is 82.4F, the humidity is 78,the cloudiness is 75, and the wind speed is 1.92.
# ------------
# Retrieving Results for Index 558: banjar.
# In banjar, the temp is 84.05F, the humidity is 61,the cloudiness is 8, and the wind speed is 3.6.
# ------------
# Retrieving Results for Index 559: skagen.
# In skagen, the temp is 33.85F, the humidity is 100,the cloudiness is 48, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 560: guajara-mirim.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=guajara-mirim&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 561: burkhala.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=burkhala&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 562: bud.
# In bud, the temp is 39.87F, the humidity is 100,the cloudiness is 92, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 563: puerto tejada.
# In puerto tejada, the temp is 75.2F, the humidity is 69,the cloudiness is 40, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 564: kloulklubed.
# In kloulklubed, the temp is 84.5F, the humidity is 97,the cloudiness is 20, and the wind speed is 10.76.
# ------------
# Retrieving Results for Index 565: aguimes.
# In aguimes, the temp is 73.4F, the humidity is 83,the cloudiness is 20, and the wind speed is 13.87.
# ------------
# Retrieving Results for Index 566: san jose.
# In san jose, the temp is 78.92F, the humidity is 96,the cloudiness is 56, and the wind speed is 1.7.
# ------------
# Retrieving Results for Index 567: kasempa.
# In kasempa, the temp is 64.25F, the humidity is 47,the cloudiness is 8, and the wind speed is 8.63.
# ------------
# Retrieving Results for Index 568: monrovia.
# In monrovia, the temp is 74.87F, the humidity is 100,the cloudiness is 88, and the wind speed is 8.97.
# ------------
# Retrieving Results for Index 569: montijo.
# In montijo, the temp is 64.47F, the humidity is 82,the cloudiness is 0, and the wind speed is 4.7.
# ------------
# Retrieving Results for Index 570: dabakala.
# In dabakala, the temp is 70.73F, the humidity is 98,the cloudiness is 92, and the wind speed is 5.73.
# ------------
# Retrieving Results for Index 571: igbo ora.
# In igbo ora, the temp is 73.7F, the humidity is 97,the cloudiness is 88, and the wind speed is 5.61.
# ------------
# Retrieving Results for Index 572: dedougou.
# In dedougou, the temp is 70.91F, the humidity is 96,the cloudiness is 44, and the wind speed is 3.15.
# ------------
# Retrieving Results for Index 573: cochrane.
# In cochrane, the temp is 32.48F, the humidity is 67,the cloudiness is 8, and the wind speed is 6.73.
# ------------
# Retrieving Results for Index 574: abhar.
# In abhar, the temp is 39.32F, the humidity is 88,the cloudiness is 0, and the wind speed is 1.48.
# ------------
# Retrieving Results for Index 575: ibra.
# In ibra, the temp is 66.5F, the humidity is 67,the cloudiness is 0, and the wind speed is 2.59.
# ------------
# Retrieving Results for Index 576: gwembe.
# In gwembe, the temp is 63.8F, the humidity is 70,the cloudiness is 0, and the wind speed is 7.29.
# ------------
# Retrieving Results for Index 577: viedma.
# In viedma, the temp is 53.27F, the humidity is 27,the cloudiness is 20, and the wind speed is 14.79.
# ------------
# Retrieving Results for Index 578: bunbury.
# In bunbury, the temp is 53.74F, the humidity is 93,the cloudiness is 90, and the wind speed is 12.75.
# ------------
# Retrieving Results for Index 579: sembe.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=sembe&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 580: dera bugti.
# In dera bugti, the temp is 77.3F, the humidity is 29,the cloudiness is 0, and the wind speed is 3.94.
# ------------
# Retrieving Results for Index 581: baherden.
# In baherden, the temp is 66.95F, the humidity is 68,the cloudiness is 36, and the wind speed is 2.37.
# ------------
# Retrieving Results for Index 582: kalamare.
# In kalamare, the temp is 44.63F, the humidity is 69,the cloudiness is 0, and the wind speed is 3.94.
# ------------
# Retrieving Results for Index 583: gisborne.
# In gisborne, the temp is 62.72F, the humidity is 61,the cloudiness is 0, and the wind speed is 14.12.
# ------------
# Retrieving Results for Index 584: mamou.
# In mamou, the temp is 67.85F, the humidity is 97,the cloudiness is 64, and the wind speed is 2.59.
# ------------
# Retrieving Results for Index 585: puerto colombia.
# In puerto colombia, the temp is 78.8F, the humidity is 94,the cloudiness is 40, and the wind speed is 3.36.
# ------------
# Retrieving Results for Index 586: acapulco.
# In acapulco, the temp is 82.4F, the humidity is 83,the cloudiness is 75, and the wind speed is 5.82.
# ------------
# Retrieving Results for Index 587: bargal.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=bargal&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 588: paamiut.
# In paamiut, the temp is 38.15F, the humidity is 97,the cloudiness is 44, and the wind speed is 10.09.
# ------------
# Retrieving Results for Index 589: ruatoria.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=ruatoria&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 590: guthrie.
# In guthrie, the temp is 73.98F, the humidity is 76,the cloudiness is 1, and the wind speed is 10.29.
# ------------
# Retrieving Results for Index 591: atbasar.
# In atbasar, the temp is 36.08F, the humidity is 82,the cloudiness is 0, and the wind speed is 3.15.
# ------------
# Retrieving Results for Index 592: xining.
# In xining, the temp is 42.65F, the humidity is 76,the cloudiness is 12, and the wind speed is 3.27.
# ------------
# Retrieving Results for Index 593: mana.
# In mana, the temp is 47.34F, the humidity is 100,the cloudiness is 0, and the wind speed is 1.12.
# ------------
# Retrieving Results for Index 594: winnemucca.
# In winnemucca, the temp is 66.92F, the humidity is 4,the cloudiness is 1, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 595: komsomolskiy.
# In komsomolskiy, the temp is 31.85F, the humidity is 91,the cloudiness is 92, and the wind speed is 14.45.
# ------------
# Retrieving Results for Index 596: ipatovo.
# In ipatovo, the temp is 61.55F, the humidity is 79,the cloudiness is 32, and the wind speed is 17.47.
# ------------
# Retrieving Results for Index 597: san andres del rabanedo.
# In san andres del rabanedo, the temp is 39.2F, the humidity is 93,the cloudiness is 0, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 598: kibara.
# In kibara, the temp is 76.13F, the humidity is 63,the cloudiness is 88, and the wind speed is 7.85.
# ------------
# Retrieving Results for Index 599: haukipudas.
# In haukipudas, the temp is 33.8F, the humidity is 100,the cloudiness is 92, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 600: ye.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=ye&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 601: yulara.
# In yulara, the temp is 84.2F, the humidity is 21,the cloudiness is 68, and the wind speed is 13.87.
# ------------
# Retrieving Results for Index 602: arlit.
# In arlit, the temp is 78.74F, the humidity is 20,the cloudiness is 64, and the wind speed is 7.07.
# ------------
# Retrieving Results for Index 603: iraquara.
# In iraquara, the temp is 69.38F, the humidity is 69,the cloudiness is 0, and the wind speed is 8.08.
# ------------
# Retrieving Results for Index 604: quang ngai.
# In quang ngai, the temp is 71.9F, the humidity is 100,the cloudiness is 92, and the wind speed is 2.93.
# ------------
# Retrieving Results for Index 605: kralendijk.
# In kralendijk, the temp is 84.2F, the humidity is 74,the cloudiness is 0, and the wind speed is 16.11.
# ------------
# Retrieving Results for Index 606: omboue.
# In omboue, the temp is 77.03F, the humidity is 100,the cloudiness is 92, and the wind speed is 9.98.
# ------------
# Retrieving Results for Index 607: olga.
# In olga, the temp is 84.25F, the humidity is 43,the cloudiness is 1, and the wind speed is 6.93.
# ------------
# Retrieving Results for Index 608: chapleau.
# In chapleau, the temp is 41F, the humidity is 75,the cloudiness is 75, and the wind speed is 2.24.
# ------------
# Retrieving Results for Index 609: kwinana.
# In kwinana, the temp is 65.61F, the humidity is 63,the cloudiness is 40, and the wind speed is 11.41.
# ------------
# Retrieving Results for Index 610: kailua.
# In kailua, the temp is 84.7F, the humidity is 76,the cloudiness is 1, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 611: kemijarvi.
# Missing field/result... skipping. URL:http://api.openweathermap.org/data/2.5/weather?q=kemijarvi&units=imperial&APPID=a58509ec13b69fb2ddc509a7404ef42d
# ------------
# Retrieving Results for Index 612: restrepo.
# In restrepo, the temp is 75.2F, the humidity is 69,the cloudiness is 40, and the wind speed is 8.05.
# ------------
# Retrieving Results for Index 613: san rafael.
# In san rafael, the temp is 36.17F, the humidity is 45,the cloudiness is 0, and the wind speed is 5.39.
# ------------
# Retrieving Results for Index 614: lisakovsk.
# In lisakovsk, the temp is 33.65F, the humidity is 87,the cloudiness is 0, and the wind speed is 6.73.
# ------------
# Retrieving Results for Index 615: manokwari.
# In manokwari, the temp is 81.71F, the humidity is 100,the cloudiness is 44, and the wind speed is 9.42.
# ------------
# Retrieving Results for Index 616: yarim.
# In yarim, the temp is 49.58F, the humidity is 55,the cloudiness is 8, and the wind speed is 5.39.
# ------------
# Retrieving Results for Index 617: alamosa.
# In alamosa, the temp is 53.06F, the humidity is 85,the cloudiness is 90, and the wind speed is 5.82.
# ------------

# %%
#Dropping cities with missing values
weather_df = weather_df.dropna(how = 'any')
# Out:
# City           553
# Temperature    553
# Humidity       553
# Cloudiness     553
# Wind Speed     553
# Latitude       553
# Longitude      553
# dtype: int64
